# %%
import pandas as pd
import numpy as np

fma_metadata_path = r"C:/Users/ross9/Downloads/fma_metadata/fma_metadata/tracks.csv" #Set this as the path to fma metadata file on your machine as it exceeds github file size limit
df_metadata = pd.read_csv(fma_metadata_path, low_memory=False) 

df_metadata.head()
# Out:
#   track_id album_comments album_date_created album_date_released  \
# 0        2              0    11/26/2008 1:44       1/5/2009 0:00
# 1        3              0    11/26/2008 1:44       1/5/2009 0:00
# 2        5              0    11/26/2008 1:44       1/5/2009 0:00
# 3       10              0    11/26/2008 1:45       2/6/2008 0:00
# 4       20              0    11/26/2008 1:45       1/6/2009 0:00
#
#   album_engineer album_favorites album_id  \
# 0            NaN               4        1
# 1            NaN               4        1
# 2            NaN               4        1
# 3            NaN               4        6
# 4            NaN               2        4
#
#                            album_information album_listens album_producer  \
# 0                                    <p></p>          6073            NaN
# 1                                    <p></p>          6073            NaN
# 2                                    <p></p>          6073            NaN
# ...

# %%
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136641 entries, 0 to 136640
# Columns: 104 entries, track_id to Unnamed: 103
# dtypes: object(104)
# memory usage: 108.4+ MB

# %%
print(df_metadata.columns.tolist())
# Out:
# ['track_id', 'album_comments', 'album_date_created', 'album_date_released', 'album_engineer', 'album_favorites', 'album_id', 'album_information', 'album_listens', 'album_producer', 'album_tags', 'album_title', 'album_tracks', 'album_type', 'artist_active_year_begin', 'artist_active_year_end', 'artist_associated_labels', 'artist_bio', 'artist_comments', 'artist_date_created', 'artist_favorites', 'artist_id', 'artist_latitude', 'artist_location', 'artist_longitude', 'artist_members', 'artist_name', 'artist_related_projects', 'artist_tags', 'artist_website', 'artist_wikipedia_page', 'set_split', 'set_subset', 'track_bit_rate', 'track_comments', 'track_composer', 'track_date_created', 'track_date_recorded', 'track_duration', 'track_favorites', 'track_genre_top', 'track_genres', 'track_genres_all', 'track_information', 'track_interest', 'track_language_code', 'track_license', 'track_listens', 'track_lyricist', 'track_number', 'track_publisher', 'track_tags', 'track_title', 'Unnamed: 53', 
# ...

# %%
last_col = "track_title"
df_metadata = df_metadata.loc[:, :"track_title"]
print(df_metadata.columns.tolist())
# Out:
# ['track_id', 'album_comments', 'album_date_created', 'album_date_released', 'album_engineer', 'album_favorites', 'album_id', 'album_information', 'album_listens', 'album_producer', 'album_tags', 'album_title', 'album_tracks', 'album_type', 'artist_active_year_begin', 'artist_active_year_end', 'artist_associated_labels', 'artist_bio', 'artist_comments', 'artist_date_created', 'artist_favorites', 'artist_id', 'artist_latitude', 'artist_location', 'artist_longitude', 'artist_members', 'artist_name', 'artist_related_projects', 'artist_tags', 'artist_website', 'artist_wikipedia_page', 'set_split', 'set_subset', 'track_bit_rate', 'track_comments', 'track_composer', 'track_date_created', 'track_date_recorded', 'track_duration', 'track_favorites', 'track_genre_top', 'track_genres', 'track_genres_all', 'track_information', 'track_interest', 'track_language_code', 'track_license', 'track_listens', 'track_lyricist', 'track_number', 'track_publisher', 'track_tags', 'track_title']

# %%
relevant_cols = [
    "track_id",
    "track_title",
    "artist_name",
    "album_title",
    "album_id",
]
df_metadata = df_metadata[relevant_cols]
df_metadata.head()
# Out:
#   track_id      track_title artist_name           album_title album_id
# 0        2             Food        AWOL  AWOL - A Way Of Life        1
# 1        3     Electric Ave        AWOL  AWOL - A Way Of Life        1
# 2        5       This World        AWOL  AWOL - A Way Of Life        1
# 3       10          Freeway   Kurt Vile     Constant Hitmaker        6
# 4       20  Spiritual Level  Nicky Cook                 Niris        4

# %%
df_metadata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136641 entries, 0 to 136640
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   track_id     136553 non-null  object
#  1   track_title  106211 non-null  object
#  2   artist_name  106682 non-null  object
#  3   album_title  106404 non-null  object
#  4   album_id     109067 non-null  object
# dtypes: object(5)
# memory usage: 39.4 MB

# %%
df_metadata.to_csv('./data/cleaned_fma_metadata.csv', index=False)
